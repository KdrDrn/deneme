# %% [markdown]
# <img src="https://miro.medium.com/max/647/1*ZOcUPrSXLYucFxppoI-dYg.png">

# %% [markdown]
# - ``Problem Statement:``
#
#     - A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts. They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
#         - Which variables are significant in predicting the price of a car?
#         - How well those variables describe the price of a car?
#
#     - Based on various market surveys, the consulting firm has gathered a large data set of different types of cars across the America market.
#
# - ``Business Goal:``
#
#    - We are required to model the price of cars with the available independent variables. It will be used by the management to understand how exactly the prices vary with the independent variables.
#    - They can accordingly manipulate the design of the cars, the business strategy etc. to meet certain price levels.
#    - Further, the model will be a good way for management to understand the pricing dynamics of a new market.
#
# - ``Please Note:``
#     - The dataset provided is for learning purpose. Please don’t draw any inference with real world scenario.

# %% [markdown]
# # Problem definition

# %% [markdown]
# - For this project we are using a car dataset, where we want to predict the selling price of car based on its certain features.
# - Since we need to find the real value, with real calculation, therefore this problem is regression problem.
#     - We will be using firstly linear regression to solve this problem. We will also compare some other regression algorithms.
#
#     - General equation of Multiple Linear Regression:
#
# $$y = \beta_0 + \beta_{1}x_1 + \beta_{2}x_2 + \beta_{3}x_3 + \beta_{4}x_4 + ... + \beta_{n}x_n$$

# %% [markdown]
# # Libraries

# %%
# Colab Installments
# !pip install pyforest
# !pip install squarify
# !pip install pyclustertend
# !pip install catboost
# !pip install optuna
# !pip install pandas_profiling
# !pip install termcolor
# !pip install colorama
# !pip install shap
# !pip install h5py

# Lazy Predictors

# !pip install pycaret[full]
# install the nightly build
# !pip install pycaret-nightly
# !pip install pycaret-nightly[full]
# !pip install scikit-learn==0.23.2  # For Pycaret
# https://pycaret.readthedocs.io/en/latest/index.html#

# !pip install scikit-learn==0.23.1  # For Lazy Predict
# !pip install lazypredict
# https://lazypredict.readthedocs.io/en/latest/readme.html#

# Colab Installments for Plotly
# !pip install --upgrade plotly
# !pip install jupyter-dash
import plotly.graph_objects as go
import plotly.express as px
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
# Out:
# ...
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\ata\\anaconda3\\Lib\\site-packages\\pywin32_system32\\pythoncom37.dll'
# Consider using the `--user` option or check the permissions.
#   Using cached pycaret_nightly-2.3.6.dev1646269189-py3-none-any.whl (313 kB)
# ...
#   Using cached pyLDAvis-3.3.1.tar.gz (1.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Using cached scipy-1.5.4-cp37-cp37m-win_amd64.whl (31.2 MB)
# ...
#   Using cached imbalanced_learn-0.7.0-py3-none-any.whl (167 kB)
# ...
#   Using cached Boruta-0.3-py3-none-any.whl (56 kB)
# ...

# %%
## Import Libraies

## import all main libraries automatically with pyforest
# !pip install pyforest
import pyforest

## main libraries
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.ticker as mticker

# !pip install squarify
import squarify as sq

import scipy.stats as stats
from scipy.cluster.hierarchy import linkage, dendrogram
import statsmodels.api as sm
import statsmodels.formula.api as smf
import datetime as dt
from datetime import datetime
from pyclustertend import hopkins

## pre-processing
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.compose import make_column_transformer, ColumnTransformer
from sklearn.decomposition import PCA
from sklearn.dummy import DummyClassifier
from sklearn.impute import SimpleImputer, KNNImputer

## feature Selection
from sklearn.feature_selection import SelectKBest, SelectPercentile, f_classif, f_regression, mutual_info_regression

## scaling
from sklearn.preprocessing import scale 
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures 
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import PowerTransformer 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import RobustScaler

## regression/prediction
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet, LogisticRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMClassifier, LGBMRegressor
from sklearn.tree import DecisionTreeRegressor


## ann
from sklearn.neural_network import MLPRegressor

## classification
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier, plot_tree 
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier, plot_importance

## metrics
from sklearn.metrics import plot_confusion_matrix, r2_score, mean_absolute_error, mean_squared_error
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import make_scorer, precision_score, precision_recall_curve, plot_precision_recall_curve 
from sklearn.metrics import plot_roc_curve, roc_auc_score, roc_curve, f1_score, accuracy_score, recall_score
from sklearn.metrics import silhouette_samples,silhouette_score
from sklearn.metrics.cluster import adjusted_rand_score

## model selection
from sklearn import model_selection
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold, KFold, cross_val_predict, train_test_split
from sklearn.model_selection import StratifiedKFold, GridSearchCV, cross_val_score, cross_validate

## MLearning
from sklearn.pipeline import make_pipeline, Pipeline
import optuna
from sklearn.naive_bayes import GaussianNB

## clevers
# !pip install -U pandas-profiling --user
import pandas_profiling
from pandas_profiling.report.presentation.flavours.html.templates import create_html_assets

import ipywidgets
from ipywidgets import interact
import missingno as msno 
# !pip install wordcloud
from wordcloud import WordCloud

# !pip install termcolor
import colorama
from colorama import Fore, Style  # makes strings colored
from termcolor import colored
from termcolor import cprint
# grey red green yellow blue magenta cyan white (on_grey ..)
# bold dark underline blink reverse concealed
# cprint("Have a first look to:","blue","on_grey", attrs=['bold'])

## plotly and cufflinks
import plotly 
import plotly.express as px
import cufflinks as cf
import plotly.graph_objs as go
import plotly.offline as py
from plotly.offline import iplot
from plotly.subplots import make_subplots
import plotly.figure_factory as ff
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)

## Ignore Warnings
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

## Figure&Display options
plt.rcParams["figure.figsize"] = (10,6)
pd.set_option('max_colwidth',200)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 200)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
plt.style.use(["default","dark_background"])
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Some User Defined Useful Functions

# %%
## Some Useful User-Defined-Functions

###############################################################################

def missing_values(df):
    missing_number = df.isnull().sum().sort_values(ascending=False)
    missing_percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    missing_values = pd.concat([missing_number, missing_percent], axis=1, keys=['Missing_Number', 'Missing_Percent'])
    return missing_values[missing_values['Missing_Number']>0]

###############################################################################

def first_looking(df):
    print(colored("Shape:", 'yellow', attrs=['bold']), df.shape,'\n', 
          colored('*'*100, 'red', attrs=['bold']),
          colored("\nInfo:\n",'yellow', attrs=['bold']), sep='')
    print(df.info(), '\n', 
          colored('*'*100, 'red', attrs=['bold']), sep='')
    print(colored("Number of Uniques:\n", 'yellow', attrs=['bold']), df.nunique(),'\n',
          colored('*'*100, 'red', attrs=['bold']), sep='')
    print(colored("Missing Values:\n", 'yellow', attrs=['bold']), missing_values(df),'\n', 
          colored('*'*100, 'red', attrs=['bold']), sep='')
    print(colored("All Columns:", 'yellow', attrs=['bold']), *list(df.columns), sep='\n- ') 
    print(colored('*'*100, 'red', attrs=['bold']), sep='')

    df.columns= df.columns.str.lower().str.replace('&', '_').str.replace(' ', '_')
    
    print(colored("Columns after rename:", 'yellow', attrs=['bold']), *list(df.columns), sep='\n- ')
    print(colored('*'*100, 'red', attrs=['bold']), sep='')
    
###############################################################################
## To view summary information about the columns

def summary(column):
    print(colored("Column: ",'yellow', attrs=['bold']), column)
    print(colored('*'*100, 'red', attrs=['bold']), sep='')
    print(colored("Missing values: ", 'yellow', attrs=['bold']), df[column].isnull().sum())
    print(colored('*'*100, 'red', attrs=['bold']), sep='')
    print(colored("Missing values(%): ", 'yellow', attrs=['bold']), round(df[column].isnull().sum()/df.shape[0]*100, 2))
    print(colored('*'*100, 'red', attrs=['bold']), sep='')
    print(colored("Unique values: ", 'yellow', attrs=['bold']), df[column].nunique())
    print(colored('*'*100, 'red', attrs=['bold']), sep='')
    print(colored("Value counts: \n", 'yellow', attrs=['bold']), df[column].value_counts(dropna = False), sep='')
    print(colored('*'*100, 'red', attrs=['bold']), sep='')
    
###############################################################################
## To view summary_ information about the columns

def summary_(column):
    print(colored("Column: ",'yellow', attrs=['bold']), column)
    print(colored('*'*100, 'red', attrs=['bold']), sep='')
    print(colored("Missing values: ", 'yellow', attrs=['bold']), df[column].isnull().sum())
    print(colored('*'*100, 'red', attrs=['bold']), sep='')
    print(colored("Missing values(%): ", 'yellow', attrs=['bold']), round(df[column].isnull().sum()/df.shape[0]*100, 2))
    print(colored('*'*100, 'red', attrs=['bold']), sep='')
    print(colored("Unique values: ", 'yellow', attrs=['bold']), df[column].nunique())
    print(colored('*'*100, 'red', attrs=['bold']), sep='')
                    
############################################################################### 

def multicolinearity_control(df):                    
    df_temp = df.corr()
    count = 'Done'
    feature =[]
    collinear= []
    for col in df_temp.columns:
        for i in df_temp.index:
            if abs(df_temp[col][i] > .8 and df_temp[col][i] < 1):
                    feature.append(col)
                    collinear.append(i)
                    cprint(f"multicolinearity alert in between {col} - {i}", "red", attrs=["bold"])
    else:
        cprint(f"There is NO multicollinearity problem.", "blue", attrs=["bold"])                     
                    
###############################################################################

def duplicate_values(df):
    print(colored("Duplicate check...", 'yellow', attrs=['bold']), sep='')
    duplicate_values = df.duplicated(subset=None, keep='first').sum()
    if duplicate_values > 0:
        df.drop_duplicates(keep='first', inplace=True)
        print(duplicate_values, colored(" Duplicates were dropped!"),'\n',
              colored('*'*100, 'red', attrs=['bold']), sep='')
    else:
        print(colored("There are no duplicates"),'\n',
              colored('*'*100, 'red', attrs=['bold']), sep='')     

###############################################################################
        
def drop_columns(df, drop_columns):
    if drop_columns !=[]:
        df.drop(drop_columns, axis=1, inplace=True)
        print(drop_columns, 'were dropped')
    else:
        print(colored('Missing value control...', 'yellow', attrs=['bold']),'\n',
              colored('If there is a missing value above the limit you have given, the relevant columns are dropped and an information is given.'), sep='')

###############################################################################

def drop_null(df, limit):
    for i in df.isnull().sum().index:
        if (df.isnull().sum()[i]/df.shape[0]*100)>limit:
            print(df.isnull().sum()[i], 'percent of', i ,'were null and dropped')
            df.drop(i, axis=1, inplace=True)
    print(colored('Last shape after missing value control:', 'yellow', attrs=['bold']), df.shape, '\n', 
          colored('*'*100, 'red', attrs=['bold']), sep='')

###############################################################################

def shape_control():
    print('df.shape:', df.shape)
    print('X.shape:', X.shape)
    print('y.shape:', y.shape)
    print('X_train.shape:', X_train.shape)
    print('y_train.shape:', y_train.shape)
    print('X_test.shape:', X_test.shape)
    print('y_test.shape:', y_test.shape)

###############################################################################  

## show values in bar graphic
def show_values_on_bars(axs):
    def _show_on_single_plot(ax):        
        for p in ax.patches:
            _x = p.get_x() + p.get_width() / 2
            _y = p.get_y() + p.get_height()
            value = '{:.2f}'.format(p.get_height())
            ax.text(_x, _y, value, ha="center") 
    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)
        
###############################################################################

# %% [markdown]
# # Load | Read Data

# %%
df0 = pd.read_csv("car_dataset.csv")
df = df0.copy()
df.head(3)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014          3.350          5.590       27000    Petrol
# 1      sx4  2013          4.750          9.540       43000    Diesel
# 2     ciaz  2017          7.250          9.850        6900    Petrol
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0

# %% [markdown]
# # First Looking to the Data Set

# %%
first_looking(df)
duplicate_values(df)
drop_columns(df, [])
drop_null(df, 90)
# df.describe().T
# Out:
# Shape:(301, 9)
# ****************************************************************************************************
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB
# None
# ****************************************************************************************************
# Number of Uniques:
# Car_Name          98
# Year              16
# Selling_Price    156
# ...

# %% [markdown]
# # Exploratory Data Analys | DataPreparation

# %%
df.head(10)
# Out:
#         car_name  year  selling_price  present_price  kms_driven fuel_type  \
# 0           ritz  2014          3.350          5.590       27000    Petrol
# 1            sx4  2013          4.750          9.540       43000    Diesel
# 2           ciaz  2017          7.250          9.850        6900    Petrol
# 3        wagon r  2011          2.850          4.150        5200    Petrol
# 4          swift  2014          4.600          6.870       42450    Diesel
# 5  vitara brezza  2018          9.250          9.830        2071    Diesel
# 6           ciaz  2015          6.750          8.120       18796    Petrol
# 7        s cross  2015          6.500          8.610       33429    Diesel
# 8           ciaz  2016          8.750          8.890       20273    Diesel
# 9           ciaz  2015          7.450          8.920       42367    Diesel
#
#   seller_type transmission  owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# ...

# %%
df.describe().T
# Out:
#                 count      mean       std      min       25%       50%  \
# year          299.000  2013.615     2.897 2003.000  2012.000  2014.000
# selling_price 299.000     4.590     4.984    0.100     0.850     3.510
# present_price 299.000     7.541     8.568    0.320     1.200     6.100
# kms_driven    299.000 36916.753 39015.170  500.000 15000.000 32000.000
# owner         299.000     0.043     0.249    0.000     0.000     0.000
#
#                     75%        max
# year           2016.000   2018.000
# selling_price     6.000     35.000
# present_price     9.840     92.600
# kms_driven    48883.500 500000.000
# owner             0.000      3.000

# %% [markdown]
# Some ``selling_prices`` and ``present_prices`` do not reflect real values, so especially we need to more focus on these features.

# %%
df.describe(include=object).T
# Out:
#              count unique     top freq
# car_name       299     98    city   26
# fuel_type      299      3  Petrol  239
# seller_type    299      2  Dealer  193
# transmission   299      2  Manual  260

# %%
df["car_name"].value_counts().index.sort_values()
# Out:
# Index(['800', 'Activa 3g', 'Activa 4g', 'Bajaj  ct 100', 'Bajaj Avenger 150',
#        'Bajaj Avenger 150 street', 'Bajaj Avenger 220',
#        'Bajaj Avenger 220 dtsi', 'Bajaj Avenger Street 220',
#        'Bajaj Discover 100', 'Bajaj Discover 125', 'Bajaj Dominar 400',
#        'Bajaj Pulsar  NS 200', 'Bajaj Pulsar 135 LS', 'Bajaj Pulsar 150',
#        'Bajaj Pulsar 220 F', 'Bajaj Pulsar NS 200', 'Bajaj Pulsar RS200',
#        'Hero  CBZ Xtreme', 'Hero  Ignitor Disc', 'Hero Extreme',
#        'Hero Glamour', 'Hero Honda CBZ extreme', 'Hero Honda Passion Pro',
#        'Hero Hunk', 'Hero Passion Pro', 'Hero Passion X pro',
#        'Hero Splender Plus', 'Hero Splender iSmart', 'Hero Super Splendor',
#        'Honda Activa 125', 'Honda Activa 4G', 'Honda CB Hornet 160R',
#        'Honda CB Shine', 'Honda CB Trigger', 'Honda CB Unicorn',
#        'Honda CB twister', 'Honda CBR 150', 'Honda Dream Yuga ',
#        'Honda Karizma', 'Hyosung GT250R', 'KTM 390 Duke ', 'KTM RC200',
# ...

# %% [markdown]
# - We checked the vehicle brands and noticed that some of them are motorbikes.
# - We redefined motorbikes as "Bike" and cars as "Auto", with their brands and models.

# %%
def replace_name(a, b):
    df["car_name"].replace(a, b, inplace=True)

replace_name('800','Auto,Suzuki,Alto')
replace_name('Activa 3g','Bike,Honda,Activa')
replace_name('Activa 4g','Bike,Honda,Activa')
replace_name('Bajaj  ct 100', 'Bike,Bajaj,CT')
replace_name('Bajaj Avenger 150','Bike,Bajaj,Avenger')
replace_name('Bajaj Avenger 150 street', 'Bike,Bajaj,Avenger')
replace_name('Bajaj Avenger 220', 'Bike,Bajaj,Avenger')
replace_name('Bajaj Avenger 220 dtsi', 'Bike,Bajaj,Avenger')
replace_name('Bajaj Avenger Street 220', 'Bike,Bajaj,Avenger')
replace_name('Bajaj Discover 100', 'Bike,Bajaj,Discover')
replace_name('Bajaj Discover 125', 'Bike,Bajaj,Discover')
replace_name('Bajaj Dominar 400', 'Bike,Bajaj,Dominar')
replace_name('Bajaj Pulsar  NS 200', 'Bike,Bajaj,Pulsar')
replace_name('Bajaj Pulsar 135 LS', 'Bike,Bajaj,Pulsar')
replace_name('Bajaj Pulsar 150', 'Bike,Bajaj,Pulsar')
replace_name('Bajaj Pulsar 220 F', 'Bike,Bajaj,Pulsar')
replace_name('Bajaj Pulsar NS 200', 'Bike,Bajaj,Pulsar')
replace_name('Bajaj Pulsar RS200', 'Bike,Bajaj,Pulsar')
replace_name('Hero  CBZ Xtreme', 'Bike,Hero,CBZ')
replace_name('Hero  Ignitor Disc', 'Bike,Hero,Ignitor')
replace_name('Hero Extreme', 'Bike,Hero,Extreme')
replace_name('Hero Glamour', 'Bike,Hero,Glamour')
replace_name('Hero Honda CBZ extreme', 'Bike,Hero,CBZ')
replace_name('Hero Honda Passion Pro', 'Bike,Hero,Passion')
replace_name('Hero Hunk', 'Bike,Hero,Hunk')
replace_name('Hero Passion Pro', 'Bike,Hero,Passion')
replace_name('Hero Passion X pro', 'Bike,Hero,Passion')
replace_name('Hero Splender Plus', 'Bike,Hero,Splender')
replace_name('Hero Splender iSmart', 'Bike,Hero,Splender')
replace_name('Hero Super Splendor', 'Bike,Hero,Splender')
replace_name('Honda Activa 125', 'Bike,Honda,Activa')
replace_name('Honda Activa 4G', 'Bike,Honda,Activa')
replace_name('Honda CB Hornet 160R', 'Bike,Honda,CB')
replace_name('Honda CB Shine', 'Bike,Honda,CB')
replace_name('Honda CB Trigger', 'Bike,Honda,CB')
replace_name('Honda CB Unicorn', 'Bike,Honda,CB')
replace_name('Honda CB twister', 'Bike,Honda,CB')
replace_name('Honda CBR 150', 'Bike,Honda,CB')
replace_name('Honda Dream Yuga ', 'Bike,Honda,Dream')
replace_name('Honda Karizma', 'Bike,Honda,Karizma')
replace_name('Hyosung GT250R', 'Bike,Hyosung,GT250R')
replace_name('KTM 390 Duke ', 'Bike,KTM,Duke')
replace_name('KTM RC200', 'Bike,KTM,RC')
replace_name('KTM RC390', 'Bike,KTM,RC')
replace_name('Mahindra Mojo XT300', 'Bike,Mahindra,Mojo')
replace_name('Royal Enfield Bullet 350', 'Bike,Royal Enfield,Bullet')
replace_name('Royal Enfield Classic 350', 'Bike,Royal Enfield,Classic')
replace_name('Royal Enfield Classic 500', 'Bike,Royal Enfield,Classic')
replace_name('Royal Enfield Thunder 350', 'Bike,Royal Enfield,Thunder')
replace_name('Royal Enfield Thunder 500', 'Bike,Royal Enfield,Thunder')
replace_name('Suzuki Access 125', 'Bike,Suzuki,Access')
replace_name('TVS Apache RTR 160', 'Bike,TVS,Apache')
replace_name('TVS Apache RTR 180', 'Bike,TVS,Apache')
replace_name('TVS Jupyter', 'Bike,TVS,Jupyter')
replace_name('TVS Sport ', 'Bike,TVS,Sport')
replace_name('TVS Wego', 'Bike,TVS,Wego')
replace_name('UM Renegade Mojave', 'Bike,UM Renegade,Mojave')
replace_name('Yamaha FZ  v 2.0', 'Bike,Yamaha,FZ')
replace_name('Yamaha FZ 16', 'Bike,Yamaha,FZ')
replace_name('Yamaha FZ S ', 'Bike,Yamaha,FZ')
replace_name('Yamaha FZ S V 2.0', 'Bike,Yamaha,FZ')
replace_name('Yamaha Fazer ', 'Bike,Yamaha,Fazer')
replace_name('alto 800', 'Auto,Suzuki,Alto')
replace_name('alto k10', 'Auto,Suzuki,Alto')
replace_name('amaze', 'Auto,Honda,Amaze')
replace_name('baleno', 'Auto,Suzuki,Baleno')
replace_name('brio', 'Auto,Honda,Brio')
replace_name('camry', 'Auto,Toyota,Camry')
replace_name('ciaz', 'Auto,Suzuki,Ciaz')    
replace_name('city', 'Auto,Honda,City')    
replace_name('corolla', 'Auto,Toyota,Corolla')
replace_name('corolla altis', 'Auto,Toyota,Corolla')   
replace_name('creta', 'Auto,Hyundai,Creta')    
replace_name('dzire', 'Auto,Suzuki,Dzire')
replace_name('elantra', 'Auto,Hyundai,Elantra')
replace_name('eon', 'Auto,Hyundai,Eon')
replace_name('ertiga', 'Auto,Suzuki,Ertiga')
replace_name('etios cross', 'Auto,Toyota,Etios')
replace_name('etios g', 'Auto,Toyota,Etios')
replace_name('etios gd', 'Auto,Toyota,Etios')
replace_name('etios liva', 'Auto,Toyota,Etios')
replace_name('fortuner', 'Auto,Toyota,Fortuner')
replace_name('grand i10', 'Auto,Hyundai,i10')
replace_name('i10', 'Auto,Hyundai,i10')
replace_name('i20','Auto,Hyundai,i20')
replace_name('ignis','Auto,Suzuki,Ignis')
replace_name('innova','Auto,Toyota,Innova')
replace_name('jazz','Auto,Honda,Jazz')
replace_name('land cruiser','Auto,Toyota,Land Cruiser')
replace_name('omni','Auto,Suzuki,Omni')
replace_name('ritz','Auto,Suzuki,Ritz')
replace_name('s cross','Auto,Suzuki,S Cross')
replace_name('swift','Auto,Suzuki,Swift')
replace_name('sx4','Auto,Suzuki,S Cross')
replace_name('verna','Auto,Hyundai,Verna')
replace_name('vitara brezza','Auto,Suzuki,Vitara')
replace_name('wagon r','Auto,Suzuki,Wagon')
replace_name('xcent','Auto,Hyundai,i10')

# %%
df["car_name"].value_counts().index.sort_values()
# Out:
# Index(['Auto,Honda,Amaze', 'Auto,Honda,Brio', 'Auto,Honda,City',
#        'Auto,Honda,Jazz', 'Auto,Hyundai,Creta', 'Auto,Hyundai,Elantra',
#        'Auto,Hyundai,Eon', 'Auto,Hyundai,Verna', 'Auto,Hyundai,i10',
#        'Auto,Hyundai,i20', 'Auto,Suzuki,Alto', 'Auto,Suzuki,Baleno',
#        'Auto,Suzuki,Ciaz', 'Auto,Suzuki,Dzire', 'Auto,Suzuki,Ertiga',
#        'Auto,Suzuki,Ignis', 'Auto,Suzuki,Omni', 'Auto,Suzuki,Ritz',
#        'Auto,Suzuki,S Cross', 'Auto,Suzuki,Swift', 'Auto,Suzuki,Vitara',
#        'Auto,Suzuki,Wagon', 'Auto,Toyota,Camry', 'Auto,Toyota,Corolla',
#        'Auto,Toyota,Etios', 'Auto,Toyota,Fortuner', 'Auto,Toyota,Innova',
#        'Auto,Toyota,Land Cruiser', 'Bike,Bajaj,Avenger', 'Bike,Bajaj,CT',
#        'Bike,Bajaj,Discover', 'Bike,Bajaj,Dominar', 'Bike,Bajaj,Pulsar',
#        'Bike,Hero,CBZ', 'Bike,Hero,Extreme', 'Bike,Hero,Glamour',
#        'Bike,Hero,Hunk', 'Bike,Hero,Ignitor', 'Bike,Hero,Passion',
# ...

# %%
len(df["car_name"].value_counts().index.sort_values())
# in original dataset unique car names werer 98
# Out:
# 59

# %%
df
# Out:
#                        car_name  year  selling_price  present_price  \
# 0              Auto,Suzuki,Ritz  2014          3.350          5.590
# 1           Auto,Suzuki,S Cross  2013          4.750          9.540
# 2              Auto,Suzuki,Ciaz  2017          7.250          9.850
# 3             Auto,Suzuki,Wagon  2011          2.850          4.150
# 4             Auto,Suzuki,Swift  2014          4.600          6.870
# 5            Auto,Suzuki,Vitara  2018          9.250          9.830
# 6              Auto,Suzuki,Ciaz  2015          6.750          8.120
# 7           Auto,Suzuki,S Cross  2015          6.500          8.610
# 8              Auto,Suzuki,Ciaz  2016          8.750          8.890
# 9              Auto,Suzuki,Ciaz  2015          7.450          8.920
# 10             Auto,Suzuki,Alto  2017          2.850          3.600
# 11             Auto,Suzuki,Ciaz  2015          6.850         10.380
# 12             Auto,Suzuki,Ciaz  2015          7.500          9.940
# ...

# %% [markdown]
# ``"vehicle_type"``, ``"brand"``, ``"model"`` represent better a vehicle.

# %%
df[['vehicle_type','brand', 'model']] = df["car_name"].str.split(",", expand=True)
df = df.drop('car_name', axis=1)

# %%
df.head()
# Out:
#    year  selling_price  present_price  kms_driven fuel_type seller_type  \
# 0  2014          3.350          5.590       27000    Petrol      Dealer
# 1  2013          4.750          9.540       43000    Diesel      Dealer
# 2  2017          7.250          9.850        6900    Petrol      Dealer
# 3  2011          2.850          4.150        5200    Petrol      Dealer
# 4  2014          4.600          6.870       42450    Diesel      Dealer
#
#   transmission  owner vehicle_type   brand    model
# 0       Manual      0         Auto  Suzuki     Ritz
# 1       Manual      0         Auto  Suzuki  S Cross
# 2       Manual      0         Auto  Suzuki     Ciaz
# 3       Manual      0         Auto  Suzuki    Wagon
# 4       Manual      0         Auto  Suzuki    Swift

# %%
df.columns
# Out:
# Index(['year', 'selling_price', 'present_price', 'kms_driven', 'fuel_type',
#        'seller_type', 'transmission', 'owner', 'vehicle_type', 'brand',
#        'model'],
#       dtype='object')

# %%
columns_ = ['vehicle_type', 'brand', 'model',
            'year', 'kms_driven', 'fuel_type', 'transmission',
            'seller_type', 'owner' ,'present_price', 'selling_price']

df = df.reindex(columns=columns_)
df.head(5)
# Out:
#   vehicle_type   brand    model  year  kms_driven fuel_type transmission  \
# 0         Auto  Suzuki     Ritz  2014       27000    Petrol       Manual
# 1         Auto  Suzuki  S Cross  2013       43000    Diesel       Manual
# 2         Auto  Suzuki     Ciaz  2017        6900    Petrol       Manual
# 3         Auto  Suzuki    Wagon  2011        5200    Petrol       Manual
# 4         Auto  Suzuki    Swift  2014       42450    Diesel       Manual
#
#   seller_type  owner  present_price  selling_price
# 0      Dealer      0          5.590          3.350
# 1      Dealer      0          9.540          4.750
# 2      Dealer      0          9.850          7.250
# 3      Dealer      0          4.150          2.850
# 4      Dealer      0          6.870          4.600

# %% [markdown]
# ## The Examination of Features & Target

# %% [markdown]
# ### Target

# %%
df.head(3)
# Out:
#   vehicle_type   brand    model  year  kms_driven fuel_type transmission  \
# 0         Auto  Suzuki     Ritz  2014       27000    Petrol       Manual
# 1         Auto  Suzuki  S Cross  2013       43000    Diesel       Manual
# 2         Auto  Suzuki     Ciaz  2017        6900    Petrol       Manual
#
#   seller_type  owner  present_price  selling_price
# 0      Dealer      0          5.590          3.350
# 1      Dealer      0          9.540          4.750
# 2      Dealer      0          9.850          7.250

# %% [markdown]
# We will predict selling price of a vehicle, then our target is ``"selling_price"``

# %%
target = "selling_price"
cprint(f"Have a first look to {target}:", "blue", "on_grey", attrs=["bold"])
summary(target)
# Out:
# Have a first look to selling_price:
# Column:  selling_price
# ****************************************************************************************************
# Missing values:  0
# ****************************************************************************************************
# Missing values(%):  0.0
# ****************************************************************************************************
# Unique values:  156
# ****************************************************************************************************
# Value counts:
# 0.450     8
# 0.600     8
# 5.250     7
# 4.500     7
# 0.200     6
# 4.750     6
# 0.250     5
# 0.500     5
# 1.050     5
# 4.000     5
# 5.500     5
# 0.400     5
# 3.100     4
# 3.000     4
# 1.150     4
# 0.650     4
# 0.480     4
# 6.000     4
# 0.750     4
# 0.350     4
# 2.850     3
# 1.350     3
# 9.250     3
# 1.100     3
# 2.250     3
# 3.250     3
# 1.200     3
# 7.450     3
# 0.300     3
# 7.500     3
# 2.900     3
# ...

# %% [markdown]
# ### Features

# %%
X_numerical_ = df.drop(target, axis=1).select_dtypes('number').astype('float64')
X_categorical_ = df.drop(target, axis=1).select_dtypes('object')

# %%
df.head()
# Out:
#   vehicle_type   brand    model  year  kms_driven fuel_type transmission  \
# 0         Auto  Suzuki     Ritz  2014       27000    Petrol       Manual
# 1         Auto  Suzuki  S Cross  2013       43000    Diesel       Manual
# 2         Auto  Suzuki     Ciaz  2017        6900    Petrol       Manual
# 3         Auto  Suzuki    Wagon  2011        5200    Petrol       Manual
# 4         Auto  Suzuki    Swift  2014       42450    Diesel       Manual
#
#   seller_type  owner  present_price  selling_price
# 0      Dealer      0          5.590          3.350
# 1      Dealer      0          9.540          4.750
# 2      Dealer      0          9.850          7.250
# 3      Dealer      0          4.150          2.850
# 4      Dealer      0          6.870          4.600

# %%
X_numerical_.head()
# Out:
#       year  kms_driven  owner  present_price
# 0 2014.000   27000.000  0.000          5.590
# 1 2013.000   43000.000  0.000          9.540
# 2 2017.000    6900.000  0.000          9.850
# 3 2011.000    5200.000  0.000          4.150
# 4 2014.000   42450.000  0.000          6.870

# %%
X_categorical_.head()
# Out:
#   vehicle_type   brand    model fuel_type transmission seller_type
# 0         Auto  Suzuki     Ritz    Petrol       Manual      Dealer
# 1         Auto  Suzuki  S Cross    Diesel       Manual      Dealer
# 2         Auto  Suzuki     Ciaz    Petrol       Manual      Dealer
# 3         Auto  Suzuki    Wagon    Petrol       Manual      Dealer
# 4         Auto  Suzuki    Swift    Diesel       Manual      Dealer

# %% [markdown]
# #### Categorical Features

# %%
X_categorical_.sample(5)
# Out:
#     vehicle_type   brand     model fuel_type transmission seller_type
# 5           Auto  Suzuki    Vitara    Diesel       Manual      Dealer
# 79          Auto  Toyota  Fortuner    Diesel    Automatic      Dealer
# 46          Auto  Suzuki      Ritz    Petrol       Manual      Dealer
# 42          Auto  Suzuki   S Cross    Petrol       Manual      Dealer
# 110         Bike     KTM        RC    Petrol       Manual  Individual

# %% [markdown]
# ##### "vehicle_type"

# %%
summary("vehicle_type")
# Out:
# Column:  vehicle_type
# ****************************************************************************************************
# Missing values:  0
# ****************************************************************************************************
# Missing values(%):  0.0
# ****************************************************************************************************
# Unique values:  2
# ****************************************************************************************************
# Value counts:
# Auto    198
# Bike    101
# Name: vehicle_type, dtype: int64
# ****************************************************************************************************

# %%
sns.barplot(data=df, x='vehicle_type', y='selling_price', orient="v");

# %%
df.groupby("vehicle_type")[["year", "kms_driven", "present_price", "selling_price", "owner"]].agg(["count", "min", "mean", "max"])
# Out:
#               year                      kms_driven                          \
#              count   min     mean   max      count   min      mean     max
# vehicle_type
# Auto           198  2003 2013.571  2018        198  2071 41403.919  197176
# Bike           101  2005 2013.703  2017        101   500 28120.129  500000
#
#              present_price                     selling_price              \
#                      count   min   mean    max         count   min  mean
# vehicle_type
# Auto                   198 2.280 10.883 92.600           198 0.350 6.604
# Bike                   101 0.320  0.990  3.450           101 0.100 0.641
#
#                     owner
#                 max count min  mean max
# vehicle_type
# Auto         35.000   198   0 0.035   3
# Bike          1.750   101   0 0.059   1

# %%
# ~92$ max present price und 35$ selling price could be an outlier, we need to check them in next steps.

# %% [markdown]
# ##### "brand"

# %%
summary("brand")
# Out:
# Column:  brand
# ****************************************************************************************************
# Missing values:  0
# ****************************************************************************************************
# Missing values(%):  0.0
# ****************************************************************************************************
# Unique values:  13
# ****************************************************************************************************
# Value counts:
# Honda            70
# Suzuki           50
# Hyundai          50
# Toyota           49
# Bajaj            25
# Royal Enfield    17
# Hero             15
# Yamaha            8
# TVS               8
# KTM               4
# UM Renegade       1
# Hyosung           1
# Mahindra          1
# Name: brand, dtype: int64
# ****************************************************************************************************

# %%
plt.figure(figsize=(8, 6))
sns.barplot(data=df, y='brand', x='selling_price', orient="h", palette="Blues_d");

# %%
df.groupby(["brand", "vehicle_type"])[["year", "kms_driven", "present_price", "selling_price", "owner"]].agg(["count", "min", "mean", "max"])
# Out:
#                             year                      kms_driven         \
#                            count   min     mean   max      count    min
# brand         vehicle_type
# Bajaj         Bike            25  2006 2013.200  2017         25    500
# Hero          Bike            15  2005 2012.667  2016         15   1000
# Honda         Auto            50  2006 2014.360  2017         50   4000
#               Bike            20  2007 2013.850  2017         20    500
# Hyosung       Bike             1  2014 2014.000  2014          1  16500
# Hyundai       Auto            50  2010 2014.100  2017         50   3435
# KTM           Bike             4  2014 2015.500  2017          4   4000
# Mahindra      Bike             1  2016 2016.000  2016          1  35000
# Royal Enfield Bike            17  2009 2014.235  2017         17   3000
# Suzuki        Auto            49  2003 2013.347  2018         49   2071
#               Bike             1  2008 2008.000  2008          1   1900
# ...

# %% [markdown]
# ##### "model"

# %%
summary_("model")
# Out:
# Column:  model
# ****************************************************************************************************
# Missing values:  0
# ****************************************************************************************************
# Missing values(%):  0.0
# ****************************************************************************************************
# Unique values:  59
# ****************************************************************************************************

# %%
df.sort_values(by=["vehicle_type", "selling_price"])
# Out:
#     vehicle_type          brand         model  year  kms_driven fuel_type  \
# 37          Auto         Suzuki          Alto  2003      127000    Petrol
# 47          Auto         Suzuki         Wagon  2006       65000    Petrol
# 44          Auto         Suzuki          Omni  2012       50000    Petrol
# 77          Auto         Toyota       Corolla  2004      135154    Petrol
# 28          Auto         Suzuki          Alto  2010       44542    Petrol
# 42          Auto         Suzuki       S Cross  2008       58000    Petrol
# 239         Auto        Hyundai           Eon  2012       23709    Petrol
# 281         Auto          Honda          City  2006       50456    Petrol
# 14          Auto         Suzuki         Dzire  2009       77427    Petrol
# 39          Auto         Suzuki       S Cross  2003       62000    Petrol
# 273         Auto          Honda          Jazz  2010       61203    Petrol
# 31          Auto         Suzuki          Ritz  2011       54200    Petrol
# ...

# %%
# with Seaborn
data = df.groupby(["vehicle_type", "model"])[["selling_price"]].mean().sort_values(by=["vehicle_type", 
                                                                                       "selling_price"]).reset_index()
fig, ax = plt.subplots(1, 2, figsize=(16, 9), sharey=False)

sns.barplot(data=data, 
            y=data[data["vehicle_type"]=="Auto"]["model"].values, 
            x=data[data["vehicle_type"]=="Auto"]["selling_price"], palette="Blues_d", ax=ax[0]);
ax[0].set_title("Auto");
sns.barplot(data=data, 
            y=data[data["vehicle_type"]=="Bike"]["model"].values, 
            x=data[data["vehicle_type"]=="Bike"]["selling_price"], palette="Blues_d", ax=ax[1]);
ax[1].set_title("Bike");

# %%
# with Plotly
from plotly.subplots import make_subplots
import plotly.graph_objects as go

import plotly.io as pio
pio.templates

fig = make_subplots(rows=1, cols=2, subplot_titles=("Autos","Bikes"), shared_yaxes=False)

fig.add_trace(go.Bar(x=list(data[data["vehicle_type"]=="Auto"]["model"].values), 
                     y=list(data[data["vehicle_type"]=="Auto"]["selling_price"])), row=1, col=1)

fig.add_trace(go.Bar(x=list(data[data["vehicle_type"]=="Bike"]["model"].values), 
                     y=list(data[data["vehicle_type"]=="Bike"]["selling_price"])), row=1, col=2)

fig.update_layout(width=1200, height=600, template="plotly_dark",
                  title_text="Selling Price", showlegend=False)
fig.show();
# Out:
# <div>                            <div id="a6ecab69-8c3a-48dc-962b-a3daa3bddb9e" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6ecab69-8c3a-48dc-962b-a3daa3bddb9e")) {                    Plotly.newPlot(                        "a6ecab69-8c3a-48dc-962b-a3daa3bddb9e",                        [{"x":["Omni","Alto","Camry","Wagon","Ritz","Eon","S Cross","Etios","Amaze","i10","Dzire","Swift","Brio","i20","Ignis","Jazz","Baleno","Verna","Ertiga","Corolla","City","Ciaz","Vitara","Elantra","Creta","Innova","Fortuner","Land Cruiser"],"y":[1.25,2.292857142857143,2.5,2.5125,2.8625,2.9,3.6357142857142857,4.204545454545454,4.2214285714285715,4.359375,4.475,4.54,4.745,4.766666666666667,4.9,5.828571428571428,5.85,6.107857142857143,6.58,6.8488235294117645,7.419230
# ...

# %%
# Plotly for loop example 
for i in ["Auto", "Bike"]:
    fig = px.bar(y=data[data["vehicle_type"]==i]["selling_price"], 
                 x=data[data["vehicle_type"]==i]["model"],
                 labels={"x": "Model", "y": "Selling Price"},
                 width=800, height=600, template="plotly_dark",
                 title=i).update_xaxes(categoryorder="total descending", tickangle=315)

    fig.show();
# Out:
# <div>                            <div id="3566a48c-924e-469b-b126-a411ee0d3f76" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3566a48c-924e-469b-b126-a411ee0d3f76")) {                    Plotly.newPlot(                        "3566a48c-924e-469b-b126-a411ee0d3f76",                        [{"alignmentgroup":"True","hovertemplate":"Model=%{x}<br>Selling Price=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Omni","Alto","Camry","Wagon","Ritz","Eon","S Cross","Etios","Amaze","i10","Dzire","Swift","Brio","i20","Ignis","Jazz","Baleno","Verna","Ertiga","Corolla","City","Ciaz","Vitara","Elantra","Creta","Innova","Fortuner"
# ...

# %%
df.groupby(["model", "vehicle_type"])[["year", "kms_driven", "present_price", "selling_price", "owner"]].agg(["count", "min", "mean", "max"])
# Out:
#                            year                      kms_driven          \
#                           count   min     mean   max      count     min
# model        vehicle_type
# Access       Bike             1  2008 2008.000  2008          1    1900
# Activa       Bike             6  2008 2015.167  2017          6     500
# Alto         Auto             7  2003 2012.857  2017          7    2135
# Amaze        Auto             7  2014 2014.429  2015          7   19000
# Apache       Bike             5  2011 2013.600  2017          5    6000
# Avenger      Bike             8  2010 2014.750  2017          8     500
# Baleno       Auto             1  2016 2016.000  2016          1   24524
# Brio         Auto            10  2012 2014.800  2017         10    5464
# Bullet       Bike             1  2016 2016.000  2016          1    6000
# CB           Bike            11  2007 2013.455  2017         11    3000
# CBZ          Bike             2  2008 2009.500  2011          2   50000
# ...

# %% [markdown]
# !!!Land Cruiser Auto, we will drop it.

# %%
df[df["model"] == "Land Cruiser"]
# Out:
#    vehicle_type   brand         model  year  kms_driven fuel_type  \
# 86         Auto  Toyota  Land Cruiser  2010       78000    Diesel
#
#    transmission seller_type  owner  present_price  selling_price
# 86       Manual      Dealer      0         92.600         35.000

# %%
list(df[(df["model"] == "Land Cruiser")].index)
# Out:
# [86]

# %%
df.drop(list(df[(df["model"] == "Land Cruiser")].index), axis = 0, inplace = True)

# %%
df[df["model"] == "Land Cruiser"]
# Out:
# Empty DataFrame
# Columns: [vehicle_type, brand, model, year, kms_driven, fuel_type, transmission, seller_type, owner, present_price, selling_price]
# Index: []

# %%
df[df["vehicle_type"]=="Auto"].groupby("model")[["present_price"]].agg("mean").sort_values(by="present_price", ascending=False)
# Out:
#           present_price
# model
# Fortuner         30.745
# Camry            23.730
# Innova           17.847
# Corolla          17.275
# Elantra          14.790
# Creta            13.600
# City             11.792
# Vitara            9.830
# Ciaz              9.757
# Verna             9.400
# Ertiga            9.390
# Jazz              8.157
# S Cross           8.144
# Baleno            7.870
# Dzire             7.633
# i20               7.206
# Etios             7.053
# Amaze             6.786
# Swift             6.342
# Brio              6.044
# Ignis             5.710
# i10               5.614
# Ritz              5.338
# Wagon             4.450
# Eon               4.430
# Alto              3.569
# Omni              2.690

# %%
df[df["vehicle_type"]=="Bike"].groupby("model")[["present_price"]].agg("mean").sort_values(by="present_price", ascending=False)
# Out:
#           present_price
# model
# GT250R            3.450
# Duke              2.400
# RC                1.977
# Mojave            1.820
# Thunder           1.671
# Dominar           1.600
# Classic           1.532
# Mojo              1.400
# Bullet            1.170
# Karizma           1.050
# Avenger           0.912
# Pulsar            0.894
# Fazer             0.880
# FZ                0.836
# Apache            0.816
# Extreme           0.787
# CBZ               0.787
# CB                0.785
# Hunk              0.750
# Ignitor           0.650
# Access            0.580
# Glamour           0.570
# Passion           0.540
# Dream             0.540
# Discover          0.537
# Splender          0.532
# Activa            0.527
# Jupyter           0.520
# Sport             0.520
# Wego              0.520
# CT                0.320

# %% [markdown]
# ##### "fuel_type"

# %%
summary("fuel_type")
# Out:
# Column:  fuel_type
# ****************************************************************************************************
# Missing values:  0
# ****************************************************************************************************
# Missing values(%):  0.0
# ****************************************************************************************************
# Unique values:  3
# ****************************************************************************************************
# Value counts:
# Petrol    239
# Diesel     57
# CNG         2
# Name: fuel_type, dtype: int64
# ****************************************************************************************************

# %% [markdown]
# !!!CNG.There are 2 observation for CNG type Autos, it is not enough to training process, so we will drop it.

# %%
df.drop(list(df[(df["fuel_type"] == "CNG")].index), axis = 0, inplace = True)
df[df["fuel_type"] == "CNG"]
# Out:
# Empty DataFrame
# Columns: [vehicle_type, brand, model, year, kms_driven, fuel_type, transmission, seller_type, owner, present_price, selling_price]
# Index: []

# %%
df["fuel_type"].value_counts()
# Out:
# Petrol    239
# Diesel     57
# Name: fuel_type, dtype: int64

# %%
df.groupby(["fuel_type", "vehicle_type"])[["year", "kms_driven", "present_price", "selling_price", "owner"]].agg(["count", "min", "mean", "max"])
# Out:
#                         year                      kms_driven                  \
#                        count   min     mean   max      count   min      mean
# fuel_type vehicle_type
# Diesel    Auto            57  2005 2014.018  2018         57  2071 50196.404
# Petrol    Auto           138  2003 2013.420  2017        138  2135 37487.558
#           Bike           101  2005 2013.703  2017        101   500 28120.129
#
#                                present_price                      \
#                            max         count   min   mean    max
# fuel_type vehicle_type
# Diesel    Auto          197176            57 5.700 14.296 36.230
# Petrol    Auto          142000           138 2.280  8.945 23.730
#           Bike          500000           101 0.320  0.990  3.450
#
#                        selling_price                    owner
#                                count   min  mean    max count min  mean max
# fuel_type vehicle_type
# ...

# %% [markdown]
# ##### "transmission"

# %%
summary("transmission")
# Out:
# Column:  transmission
# ****************************************************************************************************
# Missing values:  0
# ****************************************************************************************************
# Missing values(%):  0.0
# ****************************************************************************************************
# Unique values:  2
# ****************************************************************************************************
# Value counts:
# Manual       257
# Automatic     39
# Name: transmission, dtype: int64
# ****************************************************************************************************

# %%
df.groupby(["transmission", "vehicle_type"])[["year", "kms_driven", "present_price", "selling_price", "owner"]].agg(["count", "min", "mean", "max"])
# Out:
#                            year                      kms_driven        \
#                           count   min     mean   max      count   min
# transmission vehicle_type
# Automatic    Auto            30  2004 2013.567  2017         30  6000
#              Bike             9  2008 2013.667  2017          9   500
# Manual       Auto           165  2003 2013.600  2018        165  2071
#              Bike            92  2005 2013.707  2017         92   500
#
#                                             present_price                      \
#                                mean     max         count   min   mean    max
# transmission vehicle_type
# Automatic    Auto         50183.967  142000            30 5.700 19.241 36.230
#              Bike         64111.111  500000             9 0.510  0.531  0.580
# Manual       Auto         39569.448  197176           165 2.280  8.922 20.910
#              Bike         24599.272  213000            92 0.320  1.035  3.450
#
# ...

# %% [markdown]
# ##### "seller_type"

# %%
summary("seller_type")
# Out:
# Column:  seller_type
# ****************************************************************************************************
# Missing values:  0
# ****************************************************************************************************
# Missing values(%):  0.0
# ****************************************************************************************************
# Unique values:  2
# ****************************************************************************************************
# Value counts:
# Dealer        190
# Individual    106
# Name: seller_type, dtype: int64
# ****************************************************************************************************

# %%
df.groupby(["seller_type", "vehicle_type"])[["year", "kms_driven", "present_price", "selling_price", "owner"]].agg(["count", "min", "mean", "max"])
# Out:
#                           year                      kms_driven         \
#                          count   min     mean   max      count    min
# seller_type vehicle_type
# Dealer      Auto           190  2003 2013.721  2018        190   2071
# Individual  Auto             5  2003 2008.800  2017          5  16200
#             Bike           101  2005 2013.703  2017        101    500
#
#                                             present_price                      \
#                                mean     max         count   min   mean    max
# seller_type vehicle_type
# Dealer      Auto          39601.463  197176           190 2.690 10.400 36.230
# Individual  Auto         102040.000  142000             5 2.280 14.664 30.610
#             Bike          28120.129  500000           101 0.320  0.990  3.450
#
#                          selling_price                    owner
#                                  count   min  mean    max count min  mean max
# seller_type vehicle_type
# ...

# %% [markdown]
# - We would like to check these five autos from individual seller type, wheter they are really autos or not.

# %%
df[(df["seller_type"] == "Individual") & (df["vehicle_type"] == "Auto")]
# Out:
#    vehicle_type   brand     model  year  kms_driven fuel_type transmission  \
# 27         Auto  Suzuki     Swift  2017       16200    Petrol       Manual
# 37         Auto  Suzuki      Alto  2003      127000    Petrol       Manual
# 53         Auto  Toyota  Fortuner  2013      135000    Diesel    Automatic
# 54         Auto  Toyota    Innova  2005       90000    Petrol       Manual
# 85         Auto  Toyota     Camry  2006      142000    Petrol    Automatic
#
#    seller_type  owner  present_price  selling_price
# 27  Individual      0          6.490          6.000
# 37  Individual      0          2.280          0.350
# 53  Individual      0         30.610         16.000
# 54  Individual      0         10.210          2.750
# 85  Individual      3         23.730          2.500

# %% [markdown]
# #### Numerical Features

# %%
X_numerical_.sample(5)
# Out:
#         year  kms_driven  owner  present_price
# 158 2017.000    8600.000  0.000          0.540
# 235 2017.000   15141.000  0.000          9.400
# 101 2017.000    1400.000  0.000          1.820
# 174 2015.000   38600.000  0.000          0.720
# 143 2016.000   25000.000  0.000          0.840

# %%
def check_dist(df, var):
    plt.figure(figsize=(16, 7))
    
    plt.subplot(121)
    sns.histplot(x=var, data=df, kde=True)
    
    plt.subplot(122)
    stats.probplot(var.values, dist="norm", plot=plt)
    
    plt.show();
    
# %matplotlib inline
for i in X_numerical_.columns:
    check_dist(df, X_numerical_[i])

# %%
sns.heatmap(df.corr(), annot=True);

# %%
df.groupby(["year", "vehicle_type"])[["kms_driven", "present_price", "selling_price", "owner"]].agg(["count", "min", "mean", "max"])
# Out:
#                   kms_driven                            present_price         \
#                        count     min       mean     max         count    min
# year vehicle_type
# 2003 Auto                  2   62000  94500.000  127000             2  2.280
# 2004 Auto                  1  135154 135154.000  135154             1 12.350
# 2005 Auto                  3   75000 120725.333  197176             3 10.210
#      Bike                  1   55000  55000.000   55000             1  0.570
# 2006 Auto                  3   50456  85818.667  142000             3  4.150
#      Bike                  1   92233  92233.000   92233             1  0.750
# 2007 Bike                  2   49000  51000.000   53000             2  0.580
# 2008 Auto                  2   58000  73500.000   89000             2  7.150
#      Bike                  5    1900 127580.000  500000             5  0.520
# 2009 Auto                  5   62000  73384.600   87934             5  7.210
# ...

# %% [markdown]
# ##### "year"

# %%
summary("year")
# Out:
# Column:  year
# ****************************************************************************************************
# Missing values:  0
# ****************************************************************************************************
# Missing values(%):  0.0
# ****************************************************************************************************
# Unique values:  16
# ****************************************************************************************************
# Value counts:
# 2015    59
# 2016    49
# 2014    38
# 2017    35
# 2013    33
# 2012    23
# 2011    18
# 2010    14
# 2008     7
# 2009     6
# 2006     4
# 2005     4
# 2003     2
# 2007     2
# 2018     1
# 2004     1
# Name: year, dtype: int64
# ****************************************************************************************************

# %% [markdown]
# -  Since there are not enough observations for the model to learn tot the dataset well, we dropped these values below 2010 and including 2018. We can artificially enlarge this data set with Smote. But we will do it in future work.

# %%
df[(df["year"] < 2010)  | (df["year"] == 2018)].groupby(["year", "vehicle_type", "brand", "model"])[["kms_driven", "present_price", "selling_price", "owner"]].agg(["count", "min", "mean", "max"])
# Out:
#                                          kms_driven                     \
#                                               count     min       mean
# year vehicle_type brand         model
# 2003 Auto         Suzuki        Alto              1  127000 127000.000
#                                 S Cross           1   62000  62000.000
# 2004 Auto         Toyota        Corolla           1  135154 135154.000
# 2005 Auto         Toyota        Innova            3   75000 120725.333
#      Bike         Hero          Splender          1   55000  55000.000
# 2006 Auto         Honda         City              1   50456  50456.000
#                   Suzuki        Wagon             1   65000  65000.000
#                   Toyota        Camry             1  142000 142000.000
#      Bike         Bajaj         Pulsar            1   92233  92233.000
# 2007 Bike         Hero          Hunk              1   49000  49000.000
#                   Honda         CB                1   53000  53000.000
# ...

# %%
df[(df["year"] < 2010)  | (df["year"] == 2018)]
# Out:
#     vehicle_type          brand     model  year  kms_driven fuel_type  \
# 5           Auto         Suzuki    Vitara  2018        2071    Diesel
# 14          Auto         Suzuki     Dzire  2009       77427    Petrol
# 37          Auto         Suzuki      Alto  2003      127000    Petrol
# 39          Auto         Suzuki   S Cross  2003       62000    Petrol
# 42          Auto         Suzuki   S Cross  2008       58000    Petrol
# 47          Auto         Suzuki     Wagon  2006       65000    Petrol
# 54          Auto         Toyota    Innova  2005       90000    Petrol
# 55          Auto         Toyota   Corolla  2009       70000    Petrol
# 77          Auto         Toyota   Corolla  2004      135154    Petrol
# 84          Auto         Toyota    Innova  2005      197176    Diesel
# 85          Auto         Toyota     Camry  2006      142000    Petrol
# 90          Auto         Toyota   Corolla  2009       62000    Petrol
# ...

# %%
df[(df["year"] < 2010)  | (df["year"] == 2018)].index
# Out:
# Int64Index([  5,  14,  37,  39,  42,  47,  54,  55,  77,  84,  85,  90,  92,
#              94, 125, 184, 185, 189, 190, 192, 194, 196, 199, 200, 271, 281,
#             298],
#            dtype='int64')

# %%
df.drop(list(df[(df["year"] < 2010)  | (df["year"] == 2018)].index), axis = 0, inplace = True)

# %%
df.reset_index(drop = True, inplace = True)

# %%
df.shape
# Out:
# (269, 11)

# %% [markdown]
# ##### "kms_driven"

# %%
summary_("kms_driven")
# Out:
# Column:  kms_driven
# ****************************************************************************************************
# Missing values:  0
# ****************************************************************************************************
# Missing values(%):  0.0
# ****************************************************************************************************
# Unique values:  187
# ****************************************************************************************************

# %% [markdown]
# ##### "owner"

# %%
summary("owner")
# Out:
# Column:  owner
# ****************************************************************************************************
# Missing values:  0
# ****************************************************************************************************
# Missing values(%):  0.0
# ****************************************************************************************************
# Unique values:  2
# ****************************************************************************************************
# Value counts:
# 0    261
# 1      8
# Name: owner, dtype: int64
# ****************************************************************************************************

# %%
df[df["owner"] == 0][["kms_driven", "present_price", "selling_price"]].agg(["min", "mean", "max"])
# Out:
#       kms_driven  present_price  selling_price
# min      500.000          0.320          0.160
# mean   31610.552          7.329          4.822
# max   213000.000         36.230         33.000

# %%
df[df["owner"] == 1][["kms_driven", "present_price", "selling_price"]].agg(["min", "mean", "max"])
# Out:
#       kms_driven  present_price  selling_price
# min     3493.000          0.570          0.150
# mean   29668.000          3.958          2.406
# max    58000.000          7.130          5.250

# %% [markdown]
# - Owner label does not provide us with clear information. It is not clear whether the vehicle is new or how many owners it has. That's why we dropped it.

# %%
df.drop("owner", axis = 1, inplace = True)
df.head()
# Out:
#   vehicle_type   brand    model  year  kms_driven fuel_type transmission  \
# 0         Auto  Suzuki     Ritz  2014       27000    Petrol       Manual
# 1         Auto  Suzuki  S Cross  2013       43000    Diesel       Manual
# 2         Auto  Suzuki     Ciaz  2017        6900    Petrol       Manual
# 3         Auto  Suzuki    Wagon  2011        5200    Petrol       Manual
# 4         Auto  Suzuki    Swift  2014       42450    Diesel       Manual
#
#   seller_type  present_price  selling_price
# 0      Dealer          5.590          3.350
# 1      Dealer          9.540          4.750
# 2      Dealer          9.850          7.250
# 3      Dealer          4.150          2.850
# 4      Dealer          6.870          4.600

# %% [markdown]
# ##### "present_price"

# %%
summary_("present_price")
# Out:
# Column:  present_price
# ****************************************************************************************************
# Missing values:  0
# ****************************************************************************************************
# Missing values(%):  0.0
# ****************************************************************************************************
# Unique values:  132
# ****************************************************************************************************

# %%
data
# Out:
#    vehicle_type         model  selling_price
# 0          Auto          Omni          1.250
# 1          Auto          Alto          2.293
# 2          Auto         Camry          2.500
# 3          Auto         Wagon          2.513
# 4          Auto          Ritz          2.862
# 5          Auto           Eon          2.900
# 6          Auto       S Cross          3.636
# 7          Auto         Etios          4.205
# 8          Auto         Amaze          4.221
# 9          Auto           i10          4.359
# 10         Auto         Dzire          4.475
# 11         Auto         Swift          4.540
# 12         Auto          Brio          4.745
# 13         Auto           i20          4.767
# 14         Auto         Ignis          4.900
# 15         Auto          Jazz          5.829
# 16         Auto        Baleno          5.850
# 17         Auto         Verna          6.108
# 18         Auto        Ertiga          6.580
# 19         Auto       Corolla          6.849
# ...

# %%
# with Plotly
data_ = df.groupby(["vehicle_type", "model"])[["present_price"]].mean().sort_values(by=["vehicle_type", 
                                                                                        "present_price"]).reset_index()

fig = make_subplots(rows=1, cols=2, subplot_titles=("Autos","Bikes"), shared_yaxes=False)

fig.add_trace(go.Bar(x=list(data_[data_["vehicle_type"]=="Auto"]["model"].values), 
                     y=list(data_[data_["vehicle_type"]=="Auto"]["present_price"])), row=1, col=1)

fig.add_trace(go.Bar(x=list(data_[data_["vehicle_type"]=="Bike"]["model"].values), 
                     y=list(data_[data_["vehicle_type"]=="Bike"]["present_price"])), row=1, col=2)

fig.update_layout(width=1300, height=600, template="plotly_dark",
                  title_text="Selling Price", showlegend=False)
fig.show();
# Out:
# <div>                            <div id="10b56f5a-c25f-4d19-b063-296875eeda3b" class="plotly-graph-div" style="height:600px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("10b56f5a-c25f-4d19-b063-296875eeda3b")) {                    Plotly.newPlot(                        "10b56f5a-c25f-4d19-b063-296875eeda3b",                        [{"x":["Omni","Alto","Wagon","Eon","Ritz","i10","Ignis","Brio","Swift","Amaze","Etios","i20","Dzire","Baleno","Jazz","S Cross","Ertiga","Verna","Ciaz","City","Creta","Elantra","Corolla","Innova","Fortuner"],"y":[2.69,3.783333333333333,4.28,4.43,5.3375,5.61375,5.71,6.044,6.3420000000000005,6.785714285714286,7.052727272727273,7.205555555555555,7.773333333333333,7.87,8.157142857142857,8.535,9.389999999999999,9.4,9.756666666666668,12.086521739130434,13.6,14.79,17.29
# ...

# %%
df.head()
# Out:
#   vehicle_type   brand    model  year  kms_driven fuel_type transmission  \
# 0         Auto  Suzuki     Ritz  2014       27000    Petrol       Manual
# 1         Auto  Suzuki  S Cross  2013       43000    Diesel       Manual
# 2         Auto  Suzuki     Ciaz  2017        6900    Petrol       Manual
# 3         Auto  Suzuki    Wagon  2011        5200    Petrol       Manual
# 4         Auto  Suzuki    Swift  2014       42450    Diesel       Manual
#
#   seller_type  present_price  selling_price
# 0      Dealer          5.590          3.350
# 1      Dealer          9.540          4.750
# 2      Dealer          9.850          7.250
# 3      Dealer          4.150          2.850
# 4      Dealer          6.870          4.600

# %%
df.shape
# Out:
# (269, 10)

# %% [markdown]
# ### Handling with Outliers

# %%
df.head(2)
# Out:
#   vehicle_type   brand    model  year  kms_driven fuel_type transmission  \
# 0         Auto  Suzuki     Ritz  2014       27000    Petrol       Manual
# 1         Auto  Suzuki  S Cross  2013       43000    Diesel       Manual
#
#   seller_type  present_price  selling_price
# 0      Dealer          5.590          3.350
# 1      Dealer          9.540          4.750

# %%
X_numerical = df.drop(target, axis=1).select_dtypes('number').astype('float64')
X_categorical = df.drop(target, axis=1).select_dtypes('object')

# %%
# %matplotlib inline
sns.boxplot(data=df[target], whis=1.5,  orient="h");

# %%
sns.boxplot(data=df[df["vehicle_type"]=="Auto"][[target]], whis=1.5,  orient="h");

# %% [markdown]
# Some selling prices seem like outlier but all of these prices belong to the brand Toyota,
# we could easly and only say that vehiceles of Toyata are expensive than others. We should keep also those.

# %%
# power_tranformer = PowerTransformer(method="yeo-johnson")
# y_ = power_tranformer.fit_transform(df[df["vehicle_type"]=="Auto"][target].values.reshape(-1, 1))
# sns.boxplot(data=y, whis=1.5,  orient="h");
# If these would have been outliers, they could have been dealt with the power transform method.

# %%
sns.boxplot(data=df[df["vehicle_type"]=="Bike"][[target]], whis=1.5,  orient="h");

# %%
sns.histplot(data=df[target]);

# %%
sns.histplot(data=df[df["vehicle_type"]=="Auto"][[target]]);

# %%
sns.histplot(data=df[df["vehicle_type"]=="Bike"][[target]]);

# %%
df[[target]].describe().T
# Out:
#                 count  mean   std   min   25%   50%   75%    max
# selling_price 269.000 4.750 4.801 0.150 1.000 4.000 6.250 33.000

# %%
df[df[target]>13].groupby(["brand", "model", "year", "fuel_type", "transmission", "seller_type"]).agg(["count", "min", "mean", "max"])
# Out:
#                                                         kms_driven          \
#                                                              count     min
# brand  model    year fuel_type transmission seller_type
# Toyota Corolla  2016 Diesel    Manual       Dealer               1   23000
#                      Petrol    Manual       Dealer               1   12000
#                 2017 Petrol    Manual       Dealer               1    8700
#        Fortuner 2012 Diesel    Automatic    Dealer               2   89000
#                 2013 Diesel    Automatic    Individual           1  135000
#                 2014 Diesel    Automatic    Dealer               2   41000
#                 2015 Diesel    Automatic    Dealer               2   40000
#                 2017 Diesel    Automatic    Dealer               1    6000
#        Innova   2016 Diesel    Automatic    Dealer               1   29000
#                 2017 Diesel    Automatic    Dealer               2   15000
# ...

# %%
df.groupby(["vehicle_type", "model", "year", "fuel_type", "transmission"])["present_price"].value_counts()
# Out:
# vehicle_type  model     year  fuel_type  transmission  present_price
# Auto          Alto      2010  Petrol     Manual        3.950            1
#                         2014  Petrol     Manual        3.460            1
#                                                        3.980            1
#                         2016  Petrol     Manual        3.760            1
#                                                        3.950            1
#                         2017  Petrol     Manual        3.600            1
#               Amaze     2014  Petrol     Manual        7.000            2
#                                                        6.400            1
#                                                        6.800            1
#                         2015  Petrol     Automatic     7.500            1
#                                          Manual        5.800            1
#                                                        7.000            1
# ...

# %% [markdown]
# Present prices of some same vehicles are different.
# And actually we don't now the other important features of the vehicles that effect the present price.
# So we could drop the preset price in model development process.

# %%
index = 0
plt.figure(figsize=(30, 26))
plt.style.use(["default","dark_background"])
sns.set_style({'axes.grid' : False}); # to get rid of grid lines
for i in X_numerical:
    index += 1
    plt.subplot(6, 5, index)
    sns.boxplot(x=i, data=df, whis=3)

# %%
df.sort_values(by="present_price", ascending=False).head(3)
# Out:
#    vehicle_type   brand     model  year  kms_driven fuel_type transmission  \
# 53         Auto  Toyota  Fortuner  2017        6000    Diesel    Automatic
# 48         Auto  Toyota  Fortuner  2014       41000    Diesel    Automatic
# 51         Auto  Toyota  Fortuner  2014       78000    Diesel    Automatic
#
#    seller_type  present_price  selling_price
# 53      Dealer         36.230         33.000
# 48      Dealer         35.960         19.990
# 51      Dealer         35.960         18.750

# %%
df[df["vehicle_type"]=="Auto"].groupby("model")[["present_price"]].agg("mean").sort_values(by="present_price",
                                                                               ascending=False).head(5)
# Out:
#           present_price
# model
# Fortuner         30.745
# Innova           20.542
# Corolla          17.299
# Elantra          14.790
# Creta            13.600

# %% [markdown]
# We would like to keep all values which seem like outliers. Because all of them are reasonable and explainable.

# %% [markdown]
# ### Handling with Missing Values

# %%
df.isnull().sum()
# Out:
# vehicle_type     0
# brand            0
# model            0
# year             0
# kms_driven       0
# fuel_type        0
# transmission     0
# seller_type      0
# present_price    0
# selling_price    0
# dtype: int64

# %% [markdown]
# We have no missing values.

# %% [markdown]
# # Train-Test Split | Dummy

# %%
df.head()
# Out:
#   vehicle_type   brand    model  year  kms_driven fuel_type transmission  \
# 0         Auto  Suzuki     Ritz  2014       27000    Petrol       Manual
# 1         Auto  Suzuki  S Cross  2013       43000    Diesel       Manual
# 2         Auto  Suzuki     Ciaz  2017        6900    Petrol       Manual
# 3         Auto  Suzuki    Wagon  2011        5200    Petrol       Manual
# 4         Auto  Suzuki    Swift  2014       42450    Diesel       Manual
#
#   seller_type  present_price  selling_price
# 0      Dealer          5.590          3.350
# 1      Dealer          9.540          4.750
# 2      Dealer          9.850          7.250
# 3      Dealer          4.150          2.850
# 4      Dealer          6.870          4.600

# %%
dummied = pd.get_dummies(X_categorical, drop_first=True)
X_dum = pd.concat([X_numerical, dummied[dummied.columns]], axis=1)

from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()
encodered = enc.fit_transform(X_categorical)
X_enc = pd.concat([X_numerical, encodered[dummied.columns]], axis=1)


if (df.dtypes==object).any():
    dummied = pd.get_dummies(X_categorical, drop_first=True)
    X_dum = pd.concat([X_numerical, dummied[dummied.columns]], axis=1)

    from sklearn.preprocessing import OrdinalEncoder
    enc = OrdinalEncoder()
    encodered = enc.fit_transform(X_categorical)
    X_enc = pd.concat([X_numerical, encodered[dummied.columns]], axis=1)
    
else:
    X = df.drop(target, axis=1).astype('float64')

# %%
# make_dtype_object = df[['categorical1','categorical2']].astype('object')  # if we have features need to be dummy!!!
X_numerical = df.drop(target, axis=1).select_dtypes('number').astype('float64')
X_categorical = df.drop(target, axis=1).select_dtypes('object')

if (df.dtypes==object).any():
    dummied = pd.get_dummies(X_categorical, drop_first=True)
    X = pd.concat([X_numerical, dummied[dummied.columns]], axis=1)
    
else:
    X = df.drop(target, axis=1).astype('float64')

y = df[target]

###############################################################################
## Train - Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.30, 
                                                    random_state=42)

###############################################################################
# Scaling
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
pd.DataFrame(X_test, columns=X.columns).head()

###############################################################################
## Columns
X_categorical_list = X_categorical.columns.to_list()
X_numerical_list = X_numerical.columns.to_list()
X_columns_list = X.columns.to_list()

# %%
shape_control()
# Out:
# df.shape: (269, 10)
# X.shape: (269, 72)
# y.shape: (269,)
# X_train.shape: (188, 72)
# y_train.shape: (188,)
# X_test.shape: (81, 72)
# y_test.shape: (81,)

# %%
pd.DataFrame(X_train, columns=X.columns).head()
# Out:
#         year  kms_driven  present_price  vehicle_type_Bike  brand_Hero  \
# 84  2017.000    1200.000          1.600                  1           0
# 243 2010.000   61203.000          7.500                  0           0
# 92  2016.000    8700.000          1.500                  1           0
# 195 2013.000   36198.000          9.400                  0           0
# 126 2014.000   15000.000          0.787                  1           1
#
#      brand_Honda  brand_Hyosung  brand_Hyundai  brand_KTM  brand_Mahindra  \
# 84             0              0              0          0               0
# 243            1              0              0          0               0
# 92             0              0              0          0               0
# 195            0              0              1          0               0
# 126            0              0              0          0               0
#
#      brand_Royal Enfield  brand_Suzuki  brand_TVS  brand_Toyota  \
# ...

# %% [markdown]
# ##  Model Building (Linear Regression)

# %% [markdown]
# # Interpret the model

# %%
# # Transformer for Pipeline
# transformer = ColumnTransformer([("ohe", OneHotEncoder(drop="if_binary"), X_categorical_list),
#                                  ("scaler", StandardScaler(), X_numerical_list)], 
#                                  remainder="passthrough")

# Models
# %matplotlib inline
models = []
models.append(("LR", LinearRegression())) 
models.append(("DTR", DecisionTreeRegressor(random_state=42)))  
models.append(("RFR", RandomForestRegressor(random_state=42)))  
models.append(("ADA", AdaBoostRegressor(random_state=42)))
models.append(("GBC", GradientBoostingRegressor(random_state=42)))
models.append(("XGB", XGBRegressor(random_state=42)))
models.append(("CAT", CatBoostRegressor(random_state=42, silent=True)))
models.append(("LGBM", LGBMRegressor(random_state=42)))
models.append(("KNN", KNeighborsRegressor()))
models.append(("SVR", SVR()))  


# Evaluate each model in turn
results = []
names = []
rmse = []
mae = []
mse = []
R2 = []

for name, model in models:
    pipe = Pipeline([("model", model)])
    # we have already scaled our dataset. If we didn't, we could scale it by using pipeline.
    kfold = KFold(n_splits=10, random_state=42, shuffle=True) # for classification problem we use StrafiedKfold
    cv_results = cross_val_score(pipe, X_train, y_train, cv=kfold, scoring='neg_mean_absolute_error')
    
    results.append(cv_results)
    names.append(name)
    
    
    print(f"{name}: {round(cv_results.mean(), 4)}")
    if name=="KNN" or name=="SVR":
        y_pred = pipe.fit(X_train_scaled, y_train).predict(X_test_scaled)
    else:
        y_pred = pipe.fit(X_train, y_train).predict(X_test)
    
#     rmse.append(np.sqrt(mean_squared_error(y_train, y_train_pred)))
#     mae.append(mean_absolute_error(y_train, y_train_pred))
#     mse.append(mean_squared_error(y_train, y_train_pred))
#     R2.append(r2_score(y_train, y_train_pred))
    rmse.append(np.sqrt(mean_squared_error(y_test, y_pred)))
    mae.append(mean_absolute_error(y_test, y_pred))
    mse.append(mean_squared_error(y_test, y_pred))
    R2.append(r2_score(y_test, y_pred))
     
compare = pd.DataFrame({"RMSE": rmse,
                        "MAE": mae,
                        "MSE": mse,
                        "R2": R2
                        }, index=names)
print("all results:\n")
print(compare)

result_df = pd.DataFrame(results, columns=[i for i in range(1, 11)], index=names).T
result_df.iplot(kind="box", boxpoints="all", title="CV Results")


for score in compare.columns:
    layout = cf.Layout(height=500, width=1200)
    compare[score].sort_values().iplot(kind="barh", title=f"{score} Score", layout=layout)
# https://plotly.com/python/horizontal-bar-charts/
# https://plotly.com/python/renderers/
# https://plotly.com/python/creating-and-updating-figures/
# https://plotly.com/python/figure-labels/

# # For Train Scores
# accuracy_scores_train = []
# recall_scores_train = []
# f1_scores_train = []
# precision_scores_train = []
# y_pred_train = model.predict(X_train)
# accuracy_scores_train.append(accuracy_score(y_train,y_pred_train))
# recall_scores_train.append(recall_score(y_train,y_pred_train))
# f1_scores_train.append(f1_score(y_train,y_pred_train))
# precision_scores_train.append(precision_score(y_train,y_pred_train))
# Out:
# LR: -0.9093
# DTR: -0.7796
# RFR: -0.6416
# ADA: -0.8887
# GBC: -0.6085
# XGB: -0.5929
# CAT: -0.5671
# LGBM: -1.0199
# KNN: -3.5578
# SVR: -3.1163
# all results:
#
#       RMSE   MAE   MSE    R2
# LR   1.442 1.024 2.079 0.904
# DTR  1.169 0.724 1.366 0.937
# RFR  1.152 0.640 1.327 0.938
# ADA  1.432 0.930 2.051 0.905
# GBC  0.855 0.515 0.732 0.966
# XGB  0.829 0.524 0.688 0.968
# CAT  0.735 0.468 0.541 0.975
# LGBM 1.561 0.983 2.436 0.887
# KNN  1.401 0.825 1.963 0.909
# SVR  2.477 1.092 6.133 0.716
# <div>                            <div id="713fe06e-1451-4c92-baba-e3feddf26d44" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
compare[score]
# Out:
# LR     0.904
# DTR    0.937
# RFR    0.938
# ADA    0.905
# GBC    0.966
# XGB    0.968
# CAT    0.975
# LGBM   0.887
# KNN    0.909
# SVR    0.716
# Name: R2, dtype: float64

# %%
scring
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2688/4256919441.py in <module>
# ----> 1 scoring
#
# NameError: name 'scoring' is not defined

# %% [markdown]
# ## First Insights to Models by Pycaret

# %%
# !pip install scikit-learn==0.23.2

# %%
from pycaret.regression import *
fraud_predictor = setup(df, 
                         target=target,
                         session_id=123,
                         train_size=0.7,
                         log_experiment=True,
                         log_plots=True,
                         experiment_name='Car Price Prediction')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2688/1028085429.py in <module>
# ----> 1 from pycaret.regression import *
#       2 fraud_classifier = setup(df,
#       3                          target=target,
#       4                          session_id=123,
#       5                          train_size=0.7,
#
# ModuleNotFoundError: No module named 'pycaret'

# %%
best_model_scores = compare_models()

# %% [markdown]
# ## First Insights to Models by Lazy Predict
# #### https://pycaret.gitbook.io/docs/#regression

# %%
# !pip install scikit-learn==0.23.1
# Out:
# ...
#   Using cached scikit_learn-0.23.1-cp37-cp37m-win_amd64.whl (6.8 MB)
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.23.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.3.post1 requires numpy<1.20,>=1.16.0, but you have numpy 1.20.3 which is incompatible.
# imbalanced-learn 0.8.1 requires scikit-learn>=0.24, but you have scikit-learn 0.23.1 which is incompatible.
#     Uninstalling scikit-learn-0.23.2:
#       Successfully uninstalled scikit-learn-0.23.2
# ...

# %%
https://docs.google.com/document/d/1MJjfkXqLgjaRakpA1-7trBOt92KXIZ3jW_ms3cNEiO8/edit?usp=sharing

# %%
from lazypredict.Supervised import LazyRegressor
lazy_predictor = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric=None, predictions=True)
models, predictions = lazy_classifier.fit(X_train, X_test, y_train, y_test)
models
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2688/1885846567.py in <module>
# ----> 1 from lazypredict.Supervised import LazyRegressor
#       2 lazy_predictor = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric=None, predictions=True)
#       3 models, predictions = lazy_classifier.fit(X_train, X_test, y_train, y_test)
#       4 models
#
# ModuleNotFoundError: No module named 'lazypredict'

# %%
pd.DataFrame(cv_results).mean()[2:]
# Out:
# Series([], dtype: float64)

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ### 4.4.1 Catboost, XGBoost, LightGBM by Default Parameters

# %%
comp_recall = []
comp_recall_name = []

# %%
# # Transformer for Pipeline
# transformer = ColumnTransformer([("ohe", OneHotEncoder(drop="if_binary"), X_categorical_list),
#                                  ("scaler", StandardScaler(), X_numerical_list)], 
#                                  remainder="passthrough")

# Models
models = []
models.append(("XGB", XGBClassifier(random_state=42, verbosity = 0)))
models.append(("LGB", LGBMClassifier(random_state=42)))
models.append(("CAT", CatBoostClassifier(random_state=42,
                                         verbose=0, 
                                         cat_features=X_categorical_list)))

# Evaluate each model in turn
results = []
names = []
f1_scores = []
recall_scores = []
precision_scores = []
roc_auc_scores = []
precision_recall_auc_scores = []

for name, model in models:
    if name != "CAT":
        pipe = Pipeline([("model", model)])
        kfold = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)
        cv_results = cross_val_score(pipe, X_train, y_train, cv=kfold, scoring="recall")

        results.append(cv_results)
        names.append(name)

        print(f"{name} MODEL: {round(cv_results.mean(), 4)}")
        y_pred = pipe.fit(X_train, y_train).predict(X_test)

        f1_scores.append(f1_score(y_test, y_pred))
        recall_scores.append(recall_score(y_test, y_pred))
        precision_scores.append(precision_score(y_test, y_pred, pos_label=0))
        roc_auc_scores.append(roc_auc_score(y_test, y_pred))
        # calculate the precision-recall auc
        precision, recall, _ = precision_recall_curve(y_test, y_pred)
        precision_recall_auc_scores.append(auc(recall, precision))
        
        comp_recall.append(recall_score(y_test, y_pred))
        comp_recall_name.append(f"{name} Default")

    else:
        
        kfold = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)
        cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring="recall")

        results.append(cv_results)
        names.append(name)

        print(f"{name} MODEL: {round(cv_results.mean(), 4)}")
        
        y_pred = model.fit(X_train, y_train, cat_features=X_categorical_list).predict(X_test)

        f1_scores.append(f1_score(y_test, y_pred))
        recall_scores.append(recall_score(y_test, y_pred))
        precision_scores.append(precision_score(y_test, y_pred, pos_label=0))
        roc_auc_scores.append(roc_auc_score(y_test, y_pred))
        # calculate the precision-recall auc
        precision, recall, _ = precision_recall_curve(y_test, y_pred)
        precision_recall_auc_scores.append(auc(recall, precision))
        
        comp_recall.append(recall_score(y_test, y_pred))
        comp_recall_name.append(f"{name} Default")
    
result_df = pd.DataFrame(results, columns=[i for i in range(1, 11)], index=names).T


compare = pd.DataFrame({"F1": f1_scores,
                        "Recall-1": recall_scores,
                        "Precision-0": precision_scores,
                        "ROC AUC": roc_auc_scores,
                        "Recall AUC": precision_recall_auc_scores
                        }, index=names)

print("\n", compare)
result_df.iplot(kind="box", boxpoints="all", title="CV Results")

layout = cf.Layout(height=300, width=1200)
for score in compare.columns:
    print(f"{score} Score")
    compare[score].sort_values().iplot(kind="barh", layout=layout, title=f"{score} Score", )
