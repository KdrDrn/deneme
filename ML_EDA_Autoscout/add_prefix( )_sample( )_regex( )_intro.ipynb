# %%
import pandas as pd
import numpy as np
import scipy as sp

# %%
df = pd.read_json("scout_car.json", lines=True, orient='columns')
df1 = df.copy()

# %% [markdown]
# ##### series.add_prefix(prefix)
# ##### series.add_suffix(suffix)
# >!!! For Series, the ROW labels are prefixed.
# ##### df.add_prefix(prefix)
# ##### df.add_suffix(suffix)
# >!!! For DataFrame, the COLUMN labels are prefixed.
#
# !! Prefix/suffix labels with string prefix/suffix.

# %%
df1.head(3).T.head(5)
# Out:
#                                                                    0  \
# url                https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                   Audi A1
# short_description        Sportback 1.4 TDI S-tronic Xenon Navi Klima
# body_type                                                     Sedans
# price                                                          15770
#
#                                                                    1  \
# url                https://www.autoscout24.com//offers/audi-a1-1-...
# make_model                                                   Audi A1
# short_description                                     1.8 TFSI sport
# body_type                                                     Sedans
# price                                                          14500
#
#                                                                    2
# ...

# %%
df1.add_prefix('ascout_').head(3).T.head(5)
# Out:
#                                                                           0  \
# ascout_url                https://www.autoscout24.com//offers/audi-a1-sp...
# ascout_make_model                                                   Audi A1
# ascout_short_description        Sportback 1.4 TDI S-tronic Xenon Navi Klima
# ascout_body_type                                                     Sedans
# ascout_price                                                          15770
#
#                                                                           1  \
# ascout_url                https://www.autoscout24.com//offers/audi-a1-1-...
# ascout_make_model                                                   Audi A1
# ascout_short_description                                     1.8 TFSI sport
# ascout_body_type                                                     Sedans
# ascout_price                                                          14500
#
# ...

# %%
df1.head(3).T.head(5)
# Out:
#                                                                    0  \
# url                https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                   Audi A1
# short_description        Sportback 1.4 TDI S-tronic Xenon Navi Klima
# body_type                                                     Sedans
# price                                                          15770
#
#                                                                    1  \
# url                https://www.autoscout24.com//offers/audi-a1-1-...
# make_model                                                   Audi A1
# short_description                                     1.8 TFSI sport
# body_type                                                     Sedans
# price                                                          14500
#
#                                                                    2
# ...

# %%
df2 = df1.url.add_prefix('ascout_')

# %%
df2
# Out:
# ascout_0        https://www.autoscout24.com//offers/audi-a1-sp...
# ascout_1        https://www.autoscout24.com//offers/audi-a1-1-...
# ascout_2        https://www.autoscout24.com//offers/audi-a1-sp...
# ascout_3        https://www.autoscout24.com//offers/audi-a1-1-...
# ascout_4        https://www.autoscout24.com//offers/audi-a1-sp...
#                                       ...
# ascout_15914    https://www.autoscout24.com//offers/renault-es...
# ascout_15915    https://www.autoscout24.com//offers/renault-es...
# ascout_15916    https://www.autoscout24.com//offers/renault-es...
# ascout_15917    https://www.autoscout24.com//offers/renault-es...
# ascout_15918    https://www.autoscout24.com//offers/renault-es...
# Name: url, Length: 15919, dtype: object

# %%
df1 = df1.add_suffix('_project')
# For the permanently change df must be assign.

# %%
df1.head(3).T.head(5)
# Out:
#                                                                            0  \
# url_project                https://www.autoscout24.com//offers/audi-a1-sp...
# make_model_project                                                   Audi A1
# short_description_project        Sportback 1.4 TDI S-tronic Xenon Navi Klima
# body_type_project                                                     Sedans
# price_project                                                          15770
#
#                                                                            1  \
# url_project                https://www.autoscout24.com//offers/audi-a1-1-...
# make_model_project                                                   Audi A1
# short_description_project                                     1.8 TFSI sport
# body_type_project                                                     Sedans
# price_project                                                          14500
#
# ...

# %% [markdown]
# ##### df.sample( )
# (n=None, frac=None, replace=False, weights=None, random_state=None, axis=None, ignore_index=False)
#
# https://www.w3resource.com/pandas/dataframe/dataframe-sample.php

# %%
df1.sample().T.head(5)
# Out:
#                                                                         9722
# url_project                https://www.autoscout24.com//offers/opel-corsa...
# make_model_project                                                Opel Corsa
# short_description_project                        "1 4 66kW (90CV) Selective"
# body_type_project                                                    Compact
# price_project                                                           9900

# %%
# n: int, optional 
df1.sample(n=3).T.head(5)
# Out:
#                                                                        1252   \
# url_project                https://www.autoscout24.com//offers/audi-a1-sp...
# make_model_project                                                   Audi A1
# short_description_project            Sportback 1.6 TDI Attraction 85 kW (116
# body_type_project                                                     Sedans
# price_project                                                          15500
#
#                                                                        7383   \
# url_project                https://www.autoscout24.com//offers/opel-astra...
# make_model_project                                                Opel Astra
# short_description_project                             1.4T S/S Selective 125
# body_type_project                                                     Sedans
# price_project                                                          14900
#
# ...

# %%
# frac: float, optional
df1.sample(frac=0.33).T.head(5)
# Out:
#                                                                        10075  \
# url_project                https://www.autoscout24.com//offers/opel-corsa...
# make_model_project                                                Opel Corsa
# short_description_project             1.4 120 Jahre AT6 IntelliLink R-Kamera
# body_type_project                                                    Compact
# price_project                                                          15490
#
#                                                                        15862  \
# url_project                https://www.autoscout24.com//offers/renault-es...
# make_model_project                                            Renault Espace
# short_description_project      INITIALE PARIS TCe 225 EDC GPF Initiale Paris
# body_type_project                                                        Van
# price_project                                                          43490
#
# ...

# %%
df.sample(frac=2, replace=True).T.head(5)
# Out:
#                                                                7593   \
# url                https://www.autoscout24.com//offers/opel-astra...
# make_model                                                Opel Astra
# short_description                          1.4 Active DIT Navi Klima
# body_type                                                     Sedans
# price                                                          25490
#
#                                                                10484  \
# url                https://www.autoscout24.com//offers/opel-insig...
# make_model                                             Opel Insignia
# short_description                             ST 2,0 CDTI Innovation
# body_type                                              Station wagon
# price                                                          18264
#
#                                                                11057  \
# ...

# %%
df.sample(n=2, weights='price', random_state=1).T.head(5)
# Out:
#                                                                6093   \
# url                https://www.autoscout24.com//offers/opel-astra...
# make_model                                                Opel Astra
# short_description                       Edition 1.6 CDTI EURO6 Klima
# body_type                                                     Sedans
# price                                                          10590
#
#                                                                12069
# url                https://www.autoscout24.com//offers/opel-insig...
# make_model                                             Opel Insignia
# short_description         GS Dynamic AT Shz Voll-LED OPC Schild/Spur
# body_type                                                     Sedans
# price                                                          22500

# %% [markdown]
# A RegEx, or Regular Expression, is a sequence of characters that forms a search pattern.
#
# RegEx can be used to check if a string contains the specified search pattern.
#
# https://www.w3schools.com/python/python_regex.asp
# https://kanoki.org/2019/11/12/how-to-use-regex-in-pandas/

# %%
# built-in package
import re

# %%
txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt)
if x:
  print("YES! We have a match!")
else:
  print("No match")
# Out:
# YES! We have a match!

# %%
txt = "The rain in Spain"
x = re.search("^The*Spain$", txt)
if x:
  print("YES! We have a match!")
else:
  print("No match")
# Out:
# No match

# %% [markdown]
# #### RegEx Functions
# The re module offers a set of functions that allows us to search a string for a match:
#
# ##### Function	Description
# >findall:	Returns a list containing all matches
#
# >search:	Returns a Match object if there is a match anywhere in the string
#
# >split:	Returns a list where the string has been split at each match
#
# >sub:	Replaces one or many matches with a string

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# The findall() Function
# The findall() function returns a list containing all matches.
# The list contains the matches in the order they are found.

txt = "The rain in Spain"
x = re.findall("ai", txt)
print(x)
# Out:
# ['ai', 'ai']

# %%
# The findall() Function
# If no matches are found, an empty list is returned:

txt = "The rain in Spain"
x = re.findall("Portugal", txt)
print(x)
# Out:
# []

# %%
# The search() Function
# The search() function searches the string for a match, 
# and returns a Match object if there is a match.
# If there is more than one match, only the first occurrence of 
# the match will be returned:

txt = "The rain in Spain"
x = re.search("\s", txt)  # Search where is the white-space character
print(x)
print("The first white-space character is started in position:", 
      x.start())
print("The first white-space character is ended in position:", 
      x.end())
# Out:
# <re.Match object; span=(3, 4), match=' '>
# The first white-space character is started in position: 3
# The first white-space character is ended in position: 4

# %%
# The split() Function
# The split() function returns a list where 
# the string has been split at each match:

txt = "The rain in Spain"
x = re.split("\s", txt)  # Split at each white-space character
print(x)
# Out:
# ['The', 'rain', 'in', 'Spain']

# %%
# You can control the number of occurrences by specifying 
# the maxsplit parameter:
txt = "The rain in Spain"
x = re.split("\s", txt, 1)
print(x)
# Out:
# ['The', 'rain in Spain']

# %%
# You can control the number of occurrences by specifying 
# the maxsplit parameter:
txt = "The rain in Spain"
x = re.split("\s", txt, 2)
print(x)
# Out:
# ['The', 'rain', 'in Spain']

# %%
# The sub() Function
# The sub() function replaces the matches with the text of your choice:

# Example
# Replace every white-space character with the number 9:

txt = "The rain in Spain"
x = re.sub("\s", "9", txt)
print(x)
# Out:
# The9rain9in9Spain

# %%
# Replace the first 2 occurrences:

txt = "The rain in Spain"
x = re.sub("\s", "9", txt, 2)
print(x)
# Out:
# The9rain9in Spain

# %%
# Match Object
# A Match Object is an object containing information about 
# the search and the result.

# Note: If there is no match, the value None will be returned, 
# instead of the Match Object.

# Example
# Do a search that will return a Match Object:

txt = "The rain in Spain"
x = re.search("ai", txt)
print(x) #this will print an object
# Out:
# <re.Match object; span=(5, 7), match='ai'>

# %%
# The Match object has properties and methods used to 
# retrieve information about the search, and the result:

# .span() returns a tuple containing the start-, 
# and end positions of the match.

# Example
# Print the position (start- and end-position) of the first match 
# occurrence.

# The regular expression looks for any words that starts with 
# an upper case "S":

txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.span())
# Out:
# (12, 17)

# %%
# .string returns the string passed into the function
# Example
# Print the string passed into the function:

txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.string)
# Out:
# The rain in Spain

# %%
# Example
# Print the part of the string where there was a match.
# The regular expression looks for any words that starts with an upper case "S":
# .group() returns the part of the string where there was a match

txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.group())
# Out:
# Spain
